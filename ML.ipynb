# %% [markdown]
# 1️⃣ Import Libraries & Load Data

# %%
# Import the modules
import psycopg2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sqlalchemy import create_engine
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from pathlib import Path
from tqdm import tqdm

# %%
# Define the connection parameters
host = 'localhost'  # or the IP address of your database server
dbname = 'StarsGalaxiesQuasars'  # Replace with your database name
user = 'postgres'  # Replace with your database username
password = '121792'  # Replace with your database password
port = '5432'  # Default PostgreSQL port

# %%
# Create the connection string
connection = f'postgresql://{user}:{password}@{host}:{port}/{dbname}'
 
# Create a connection engine using SQLAlchemy
engine = create_engine(connection)

# %%
# Write a SQL query to join the observation and classification tables
join_query = """
SELECT o.*, c.class
FROM observation o
JOIN classification c ON o.classid = c.classid;
"""

# %%
# Load the data into a Pandas DataFrame
database_df = pd.read_sql(join_query, engine)

# Check DataFrame
database_df.head()
# Out:
#    observationid  classid                objid          ra       dec  \
# 0              1        1  1237650000000000000  183.531326  0.089693
# 1              2        1  1237650000000000000  183.598370  0.135285
# 2              3        2  1237650000000000000  183.680207  0.126185
# 3              4        1  1237650000000000000  183.870529  0.049911
# 4              5        1  1237650000000000000  183.883288  0.102557
#
#           u         g         r         i         z  redshift  run  rerun  \
# 0  19.47406  17.04240  15.94699  15.50342  15.22531     752.0  301      4
# 1  18.66280  17.21449  16.67637  16.48922  16.39150     752.0  301      4
# 2  19.38298  18.19169  17.47428  17.08732  16.80125     752.0  301      4
# 3  17.76536  16.60272  16.16116  15.98233  15.90438     752.0  301      4
# 4  17.55025  16.26342  16.43869  16.55492  16.61326     752.0  301      4
#
#    camcol         field     specobjid  plate    mjd  fiberid   class
# 0     267  3.722360e+18     -8.96e-06   3306  54922      491    STAR
# 1     267  3.638140e+17     -5.49e-05    323  51615      541    STAR
# 2     268  3.232740e+17     0.1231112    287  52023      513  GALAXY
# 3     269  3.722370e+18  -0.000110616   3306  54922      510    STAR
# 4     269  3.722370e+18   0.000590357   3306  54922      512    STAR

# %% [markdown]
# 2️⃣ Exploratory Data Analysis (EDA)

# %%
print(database_df.describe())
# Out:
#        observationid       classid            ra           dec             u  \
# count    10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      5000.50000      1.669800    175.529987     14.836148     18.619355
# std       2886.89568      0.625465     47.783439     25.212207      0.828656
# min          1.00000      1.000000      8.235100     -5.382632     12.988970
# 25%       2500.75000      1.000000    157.370946     -0.539035     18.178035
# 50%       5000.50000      2.000000    180.394514      0.404166     18.853095
# 75%       7500.25000      2.000000    201.547279     35.649397     19.259232
# max      10000.00000      3.000000    260.884382     68.542265     19.599900
#
#                   g             r             i             z      redshift  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      17.371931     16.840963     16.583579     16.422833    981.034800
# std        0.945457      1.067764      1.141805      1.203188    273.305024
# min       12.799550     12.431600     11.947210     11.610410    308.000000
# 25%       16.815100     16.173333     15.853705     15.618285    752.000000
# 50%       17.495135     16.858770     16.554985     16.389945    756.000000
# 75%       18.010145     17.512675     17.258550     17.141447   1331.000000
# max       19.918970     24.802040     28.179630     22.833060   1412.000000
#
#            run         rerun        camcol         field         plate  \
# count  10000.0  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean     301.0      3.648700    302.380100  1.645022e+18   1460.986400
# std        0.0      1.666183    162.577763  2.013998e+18   1788.778371
# min      301.0      1.000000     11.000000  2.995780e+17    266.000000
# 25%      301.0      2.000000    184.000000  3.389248e+17    301.000000
# 50%      301.0      4.000000    299.000000  4.966580e+17    441.000000
# 75%      301.0      5.000000    414.000000  2.881300e+18   2559.000000
# max      301.0      6.000000    768.000000  9.468830e+18   8410.000000
#
#                 mjd       fiberid
# count  10000.000000  10000.000000
# mean   52943.533300    353.069400
# std     1511.150651    206.298149
# min    51578.000000      1.000000
# 25%    51900.000000    186.750000
# 50%    51997.000000    351.000000
# 75%    54468.000000    510.000000
# max    57481.000000   1000.000000

# %%
# Count plot of different classes
plt.figure(figsize=(8, 5))
sns.countplot(data=database_df, x='class', palette='viridis')
plt.title("Distribution of Object Classes")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Ian O'Connor\AppData\Local\Temp\ipykernel_34620\3098073525.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Set plot style
sns.set_style("whitegrid")

# Density plots for numerical columns
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
features = ['ra', 'dec', 'u', 'g', 'r', 'redshift']
for i, feature in enumerate(features):
    row, col = divmod(i, 3)
    sns.kdeplot(data=database_df, x=feature, hue='class', fill=True, ax=axes[row, col], alpha=0.5)
    axes[row, col].set_title(f"Density Plot of {feature}")

plt.tight_layout()
plt.show()

# %%
# 3D Scatter Plot of RA, DEC, and Redshift
fig = px.scatter_3d(database_df, x='ra', y='dec', z='redshift', color='class', opacity=0.7)
fig.update_layout(title="3D Scatter Plot of RA, DEC, and Redshift")
fig.show()

# %%
database_df
# Out:
#       observationid  classid                objid          ra        dec  \
# 0                 1        1  1237650000000000000  183.531326   0.089693
# 1                 2        1  1237650000000000000  183.598370   0.135285
# 2                 3        2  1237650000000000000  183.680207   0.126185
# 3                 4        1  1237650000000000000  183.870529   0.049911
# 4                 5        1  1237650000000000000  183.883288   0.102557
# ...             ...      ...                  ...         ...        ...
# 9995           9996        2  1237650000000000000  131.316413  51.539547
# 9996           9997        2  1237650000000000000  131.306083  51.671341
# 9997           9998        1  1237650000000000000  131.552562  51.666986
# 9998           9999        2  1237650000000000000  131.477151  51.753068
# 9999          10000        2  1237650000000000000  131.665012  51.805307
#
#              u         g         r         i         z  redshift  run  rerun  \
# 0     19.47406  17.04240  15.94699  15.50342  15.22531     752.0  301      4
# 1     18.66280  17.21449  16.67637  16.48922  16.39150     752.0  301      4
# 2     19.38298  18.19169  17.47428  17.08732  16.80125     752.0  301      4
# 3     17.76536  16.60272  16.16116  15.98233  15.90438     752.0  301      4
# 4     17.55025  16.26342  16.43869  16.55492  16.61326     752.0  301      4
# ...        ...       ...       ...       ...       ...       ...  ...    ...
# 9995  18.81777  17.47053  16.91508  16.68305  16.50570    1345.0  301      3
# 9996  18.27255  17.43849  17.07692  16.71661  16.69897    1345.0  301      3
# 9997  18.75818  17.77784  17.51872  17.43302  17.42048    1345.0  301      3
# 9998  18.88287  17.91068  17.53152  17.36284  17.13988    1345.0  301      3
# 9999  19.27586  17.37829  16.30542  15.83548  15.50588    1345.0  301      3
#
#       camcol         field     specobjid  plate    mjd  fiberid   class
# 0        267  3.722360e+18     -8.96e-06   3306  54922      491    STAR
# 1        267  3.638140e+17     -5.49e-05    323  51615      541    STAR
# 2        268  3.232740e+17     0.1231112    287  52023      513  GALAXY
# 3        269  3.722370e+18  -0.000110616   3306  54922      510    STAR
# 4        269  3.722370e+18   0.000590357   3306  54922      512    STAR
# ...      ...           ...           ...    ...    ...      ...     ...
# 9995     161  5.033450e+17    0.02758294    447  51877      246  GALAXY
# 9996     162  5.033400e+17     0.1177722    447  51877      228  GALAXY
# 9997     162  8.222620e+18  -0.000401573   7303  57013      622    STAR
# 9998     163  5.033400e+17    0.01401894    447  51877      229  GALAXY
# 9999     163  5.033410e+17     0.1184173    447  51877      233  GALAXY
#
# [10000 rows x 20 columns]

# %% [markdown]
# 3️⃣ Data Preprocessing

# %%
# Drop non-numeric columns except 'class'
ml = database_df.drop(columns=['observationid', 'classid', 'objid', 'specobjid', 'run', 'rerun', 'camcol', 'field', 'fiberid', 'plate', 'mjd'])

# Encode categorical target variable
le = LabelEncoder()
ml['class'] = le.fit_transform(ml['class'])

# %%
# Separate the data into labels and features
y = ml['class']
X = ml.drop(columns=['class'])

# %%
# Review the y variable Series
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    2
# Name: class, dtype: int32

# %%
# Review the target variable counts
y.value_counts()
# Out:
# class
# 0    4998
# 2    4152
# 1     850
# Name: count, dtype: int64

# %%
# Review the X variable DataFrame
X.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598370  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
#
#    redshift
# 0     752.0
# 1     752.0
# 2     752.0
# 3     752.0
# 4     752.0

# %%
# Review the feature variable counts
X.value_counts()
# Out:
# ra          dec         u         g         r         i         z         redshift
# 8.235100     14.704008  17.26167  16.06334  15.51514  15.29140  15.16316  1035.0      1
# 192.464970   0.198233   18.96585  17.54525  16.76086  16.35486  16.00846  752.0       1
# 192.266517   66.814214  19.02009  18.08086  17.56344  17.03533  16.96725  1412.0      1
# 192.386419  -0.376573   19.02828  17.04563  16.08323  15.62549  15.25828  752.0       1
# 192.399933   0.070941   18.67530  17.79995  17.54513  17.45599  17.45645  752.0       1
#                                                                                      ..
# 163.216169  -0.050241   19.25595  18.23218  17.83592  17.68170  17.61131  756.0       1
# 163.219139   1.079843   19.48174  18.62244  18.35791  18.05260  17.95066  756.0       1
# 163.223825  -0.150001   19.52019  18.11852  17.28638  16.85283  16.58734  756.0       1
# 163.230449   0.780990   19.47643  17.99841  17.38878  17.15859  17.02192  756.0       1
# 260.884382   25.807214  18.01981  16.34242  15.63478  15.32526  15.17147  1345.0      1
# Name: count, Length: 10000, dtype: int64

# %%
# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

print("Train set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Train set size: (8000, 8)
# Test set size: (2000, 8)

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit on training data and transform both train & test sets
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert back to DataFrame for readability (optional)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

# Verify scaling
print("\nScaled Feature Mean (Train):\n", X_train_scaled.mean())
print("\nScaled Feature Standard Deviation (Train):\n", X_train_scaled.std())
# Out:
# Scaled Feature Mean (Train):
#  ra         -2.700062e-16
# dec         7.327472e-18
# u           9.254819e-16
# g          -4.297007e-15
# r           2.774669e-15
# i          -7.993606e-18
# z          -6.794565e-17
# redshift    2.116085e-16
# dtype: float64
#
# Scaled Feature Standard Deviation (Train):
#  ra          1.000063
# dec         1.000063
# u           1.000063
# g           1.000063
# r           1.000063
# i           1.000063
# z           1.000063
# redshift    1.000063
# dtype: float64

# %%
# Check first few rows
X_train_scaled.head()
# Out:
#          ra       dec         u         g         r         i         z  \
# 0 -0.517787 -0.556383  0.093147 -0.553891 -0.889921 -0.983317 -1.107165
# 1 -0.304684 -0.535179  0.884337  0.118754 -0.164296 -0.310665 -0.432963
# 2  0.979421 -0.612357  0.424239  1.436133  1.595855  1.556812  1.415633
# 3  0.512531 -0.606563  0.821024  1.831825  1.816721  1.991200  2.056999
# 4  0.404117  2.103266  0.724266  0.829808  0.683354  0.562247  0.492157
#
#    redshift
# 0 -0.821167
# 1 -0.821167
# 2 -0.835829
# 3  1.297476
# 4  1.583383

# %% [markdown]
# 4️⃣ Machine Learning Models

# %% [markdown]
# 🔹 Logistic Regression

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
logistic_model = LogisticRegression(random_state=12, max_iter=100)

# Fit the model using training data
logistic_model.fit(X_train, y_train)
# Out:
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression(random_state=12)

# %%
# Make a prediction using the testing data
y_pred = logistic_model.predict(X_test)

# %%
# Print the classification report for the model
print(f"Logistic Regression Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print(f"\nLogistic Regression Model Report:\n{classification_report(y_test, y_pred)}")
# Out:
# Logistic Regression Accuracy: 0.6615
#
# Logistic Regression Model Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77       999
#            1       0.46      0.19      0.27       169
#            2       0.62      0.53      0.57       832
#
#     accuracy                           0.66      2000
#    macro avg       0.59      0.52      0.54      2000
# weighted avg       0.64      0.66      0.64      2000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# 🔹 Random Forest Classifier

# %%
# Train Random Forest Model
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1, verbose=2)
rf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100
#
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100building tree 32 of 100
#
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.1s
# building tree 60 of 100building tree 61 of 100
# building tree 62 of 100
#
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 84 of 100
# building tree 83 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.7s finished
# RandomForestClassifier(n_jobs=-1, random_state=42, verbose=2)

# %%
# Predictions
y_pred_rf = rf.predict(X_test)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
# Evaluate model performance
print(f"Random Forest Model Accuracy: {accuracy_score(y_test, y_pred_rf):.2f}")
print(f"\nRandom Forest Model Report:\n{classification_report(y_test, y_pred_rf)}")
# Out:
# Random Forest Model Accuracy: 0.91
#
# Random Forest Model Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       999
#            1       0.88      0.88      0.88       169
#            2       0.89      0.92      0.91       832
#
#     accuracy                           0.91      2000
#    macro avg       0.90      0.90      0.90      2000
# weighted avg       0.91      0.91      0.91      2000

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Feature Importance Visualization
feat_importances = pd.Series(rf.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh', figsize=(10, 6), color='teal')
plt.title("Top 10 Feature Importances - Random Forest")
plt.show()

# %% [markdown]
# 🔹 Support Vector Machine with SGD

# %%
# Initialize the model
svm_model = SGDClassifier(loss='hinge', random_state=100, max_iter=1, tol=None)
n_epochs = 100

print("\nTraining SVM with SGD:")
for epoch in tqdm(range(n_epochs), desc="Epoch Progress"):
    svm_model.partial_fit(X_train, y_train, classes=np.unique(y))
# Out:
# Training SVM with SGD:
# Epoch Progress: 100%|██████████| 100/100 [00:00<00:00, 147.26it/s]

# %%
# Make predictions
y_pred = svm_model.predict(X_test)

# %%
# Evaluate the SVM model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.416
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       999
#            1       0.00      0.00      0.00       169
#            2       0.42      1.00      0.59       832
#
#     accuracy                           0.42      2000
#    macro avg       0.14      0.33      0.20      2000
# weighted avg       0.17      0.42      0.24      2000
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# Hyperparameter Tuning

# %%
# Define the Hyperparameter Tuning grid for SVM
param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf', 'poly']}

# Set up the SVC
svc = SVC()
# Out:
# Using random_state: 634

# %%
# WARNING: THIS CODE CAN TAKE A WHILE TO RUN!
# Create a RandomizedSearchCV object with random_state for reproducibility and verbose for feedback
random_search = RandomizedSearchCV(
    svc, 
    param_grid, 
    n_iter=4, 
    cv=3, 
    scoring='accuracy', 
    n_jobs=-1,
    verbose=1, 
    random_state=634
)

# Create a custom fit method with progress bar
def fit_with_progress_bar(random_search, X_train, y_train):
    # Create a tqdm progress bar with the total number of fits (iterations)
    with tqdm(total=random_search.n_iter, desc="Randomized Search Progress", unit="trial") as pbar:
        best_score = -np.inf
        best_params = None
        
        # Manually iterate over n_iter and perform cross-validation for each parameter combination
        for _ in range(random_search.n_iter):
            # Generate a random set of parameters from the parameter grid
            params = random_search.param_distributions
            random_params = {key: np.random.choice(val) for key, val in params.items()}
            svc.set_params(**random_params)
            
            # Perform cross-validation for the current parameter combination
            cv = StratifiedKFold(n_splits=random_search.cv, shuffle=True, random_state=1)
            cv_scores = []
            for train_idx, test_idx in cv.split(X_train, y_train):
                X_train_fold, X_test_fold = X_train.iloc[train_idx], X_train.iloc[test_idx]
                y_train_fold, y_test_fold = y_train.iloc[train_idx], y_train.iloc[test_idx]
                
                # Train and score the model for the fold
                svc.fit(X_train_fold, y_train_fold)
                cv_scores.append(svc.score(X_test_fold, y_test_fold))
            
            mean_score = np.mean(cv_scores)
            
            # Update the best score and parameters if applicable
            if mean_score > best_score:
                best_score = mean_score
                best_params = random_params
            
            # Update progress bar for each trial
            pbar.update(1)
        
        return best_params, best_score

# Run the randomized search with the progress bar
best_params, best_score = fit_with_progress_bar(random_search, X_train, y_train)

# Print the best parameters and score
print(f"Completed with random_state: {random_state}")
print("\nBest SVM Parameters:", best_params)
print("\nBest Score:", best_score)
# Out:
# Randomized Search Progress: 100%|██████████| 4/4 [01:24<00:00, 21.25s/trial]
# Completed with random_state: 634
#
# Best SVM Parameters: {'C': 10.0, 'kernel': 'linear'}
#
# Best Score: 0.9371252636931261

# %%
# Train with linear kernel model
svm_linear = SVC(kernel='linear', random_state=42)
svm_linear.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Predictions
y_pred_linear = svm_linear.predict(X_test)

# %%
# Evaluate the linear Kernel Model
print("Linear Kernel Classification Report:")
print(classification_report(y_test, y_pred_linear))
print("Accuracy (linear Kernel):", accuracy_score(y_test, y_pred_linear))
# Out:
# Linear Kernel Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       999
#            1       0.91      0.86      0.88       169
#            2       0.91      0.97      0.94       832
#
#     accuracy                           0.94      2000
#    macro avg       0.93      0.92      0.92      2000
# weighted avg       0.94      0.94      0.94      2000
#
# Accuracy (linear Kernel): 0.9385

# %%
database_df
# Out:
#       observationid  classid                objid          ra        dec  \
# 0                 1        1  1237650000000000000  183.531326   0.089693
# 1                 2        1  1237650000000000000  183.598370   0.135285
# 2                 3        2  1237650000000000000  183.680207   0.126185
# 3                 4        1  1237650000000000000  183.870529   0.049911
# 4                 5        1  1237650000000000000  183.883288   0.102557
# ...             ...      ...                  ...         ...        ...
# 9995           9996        2  1237650000000000000  131.316413  51.539547
# 9996           9997        2  1237650000000000000  131.306083  51.671341
# 9997           9998        1  1237650000000000000  131.552562  51.666986
# 9998           9999        2  1237650000000000000  131.477151  51.753068
# 9999          10000        2  1237650000000000000  131.665012  51.805307
#
#              u         g         r         i         z  redshift  run  rerun  \
# 0     19.47406  17.04240  15.94699  15.50342  15.22531     752.0  301      4
# 1     18.66280  17.21449  16.67637  16.48922  16.39150     752.0  301      4
# 2     19.38298  18.19169  17.47428  17.08732  16.80125     752.0  301      4
# 3     17.76536  16.60272  16.16116  15.98233  15.90438     752.0  301      4
# 4     17.55025  16.26342  16.43869  16.55492  16.61326     752.0  301      4
# ...        ...       ...       ...       ...       ...       ...  ...    ...
# 9995  18.81777  17.47053  16.91508  16.68305  16.50570    1345.0  301      3
# 9996  18.27255  17.43849  17.07692  16.71661  16.69897    1345.0  301      3
# 9997  18.75818  17.77784  17.51872  17.43302  17.42048    1345.0  301      3
# 9998  18.88287  17.91068  17.53152  17.36284  17.13988    1345.0  301      3
# 9999  19.27586  17.37829  16.30542  15.83548  15.50588    1345.0  301      3
#
#       camcol         field     specobjid  plate    mjd  fiberid   class
# 0        267  3.722360e+18     -8.96e-06   3306  54922      491    STAR
# 1        267  3.638140e+17     -5.49e-05    323  51615      541    STAR
# 2        268  3.232740e+17     0.1231112    287  52023      513  GALAXY
# 3        269  3.722370e+18  -0.000110616   3306  54922      510    STAR
# 4        269  3.722370e+18   0.000590357   3306  54922      512    STAR
# ...      ...           ...           ...    ...    ...      ...     ...
# 9995     161  5.033450e+17    0.02758294    447  51877      246  GALAXY
# 9996     162  5.033400e+17     0.1177722    447  51877      228  GALAXY
# 9997     162  8.222620e+18  -0.000401573   7303  57013      622    STAR
# 9998     163  5.033400e+17    0.01401894    447  51877      229  GALAXY
# 9999     163  5.033410e+17     0.1184173    447  51877      233  GALAXY
#
# [10000 rows x 20 columns]

# %%
# Confusion Matrix
cm_rbf = confusion_matrix(y_test, y_pred_linear)
sns.heatmap(cm_rbf, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix (Linear Kernel)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Train SVM with an RBF kernel
svm_rbf = SVC(kernel='rbf', random_state=42)
svm_rbf.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
# Predictions
y_pred_rbf = svm_rbf.predict(X_test)

# %%
# Evaluate the RBF Kernel Model
print("RBF Kernel Classification Report:")
print(classification_report(y_test, y_pred_rbf))
print("Accuracy (RBF Kernel):", accuracy_score(y_test, y_pred_rbf))
# Out:
# RBF Kernel Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       999
#            1       0.00      0.00      0.00       169
#            2       1.00      0.01      0.02       832
#
#     accuracy                           0.50      2000
#    macro avg       0.50      0.34      0.23      2000
# weighted avg       0.67      0.50      0.34      2000
#
# Accuracy (RBF Kernel): 0.5035
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\ProgramData\Anaconda\envs\dev_2\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
# Confusion Matrix
cm_rbf = confusion_matrix(y_test, y_pred_rbf)
sns.heatmap(cm_rbf, annot=True, fmt="d", cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix (RBF Kernel)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# 5️⃣ PCA for Dimensionality Reduction

# %%
# Apply PCA to reduce to 2D for visualization
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

svm_model_pca = SGDClassifier(loss='hinge', max_iter=10000, tol=1e-3, verbose=1, random_state=100)
svm_model_pca.fit(X_train_pca, y_train)
y_pred_pca = svm_model_pca.predict(X_test_pca)
# Out:
# -- Epoch 1
# Norm: 316440525058654912.00, NNZs: 2, Bias: -2159.504915, T: 8000, Avg. loss: 1248493538233006501815255581769859072.000000
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 717430804165203200.00, NNZs: 2, Bias: -2850.892520, T: 16000, Avg. loss: 393751092630760694171055773997596672.000000
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 391112576003252608.00, NNZs: 2, Bias: -3303.784713, T: 24000, Avg. loss: 240242468196683576145442051752722432.000000
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 129382672580623648.00, NNZs: 2, Bias: -3610.599809, T: 32000, Avg. loss: 172084396857704120428644992355926016.000000
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 357423381423668864.00, NNZs: 2, Bias: -3855.773189, T: 40000, Avg. loss: 136515856972529147568899960812339200.000000
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 211718357449221.19, NNZs: 2, Bias: -4062.954944, T: 48000, Avg. loss: 111333414496000690182164700442132480.000000
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 419296060588524800.00, NNZs: 2, Bias: -4229.691915, T: 56000, Avg. loss: 95427299771360670946567710232805376.000000
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 277755021288533664.00, NNZs: 2, Bias: -4378.448643, T: 64000, Avg. loss: 82288336221352375133811609641680896.000000
# Total training time: 0.01 seconds.
# -- Epoch 9
# Norm: 133855516055003.86, NNZs: 2, Bias: -4512.157034, T: 72000, Avg. loss: 70038522281202602941424801222230016.000000
# Total training time: 0.01 seconds.
# -- Epoch 10
# Norm: 146220254184980288.00, NNZs: 2, Bias: -4635.344695, T: 80000, Avg. loss: 68003065080983946209143834596605952.000000
# Total training time: 0.01 seconds.
# -- Epoch 11
# Norm: 78041402852583296.00, NNZs: 2, Bias: -4741.832279, T: 88000, Avg. loss: 57758550531861180974407672915820544.000000
# Total training time: 0.01 seconds.
# -- Epoch 12
# Norm: 122617022108224544.00, NNZs: 2, Bias: -4833.748943, T: 96000, Avg. loss: 50964102849474684589884939605901312.000000
# Total training time: 0.01 seconds.
# -- Epoch 13
# Norm: 115973768904694080.00, NNZs: 2, Bias: -4914.590704, T: 104000, Avg. loss: 48682230229065932332790821236506624.000000
# Total training time: 0.01 seconds.
# -- Epoch 14
# Norm: 358387704603333376.00, NNZs: 2, Bias: -4998.030629, T: 112000, Avg. loss: 45690414908148100417616459962777600.000000
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 7858953968790355.00, NNZs: 2, Bias: -5073.843011, T: 120000, Avg. loss: 43582033829004466643842441425190912.000000
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 101204402524184832.00, NNZs: 2, Bias: -5145.454103, T: 128000, Avg. loss: 39685951968739640517313134141112320.000000
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 15289590544196038.00, NNZs: 2, Bias: -5210.524285, T: 136000, Avg. loss: 36431589039080611603487035261714432.000000
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 67824947387808472.00, NNZs: 2, Bias: -5271.643130, T: 144000, Avg. loss: 33741938097804944668115553038106624.000000
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 67720784130693648.00, NNZs: 2, Bias: -5329.239342, T: 152000, Avg. loss: 33767216192104614059604516033003520.000000
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 79660150932368928.00, NNZs: 2, Bias: -5386.645398, T: 160000, Avg. loss: 30811627503777965340517518490468352.000000
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 48119914400135048.00, NNZs: 2, Bias: -5442.967484, T: 168000, Avg. loss: 28723875378694358621674469800804352.000000
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 48092136396002648.00, NNZs: 2, Bias: -5496.054912, T: 176000, Avg. loss: 28978275197940854061959505434902528.000000
# Total training time: 0.01 seconds.
# -- Epoch 23
# Norm: 27239781376942892.00, NNZs: 2, Bias: -5545.417372, T: 184000, Avg. loss: 26815470519778021771618103133732864.000000
# Total training time: 0.01 seconds.
# -- Epoch 24
# Norm: 37601773603499528.00, NNZs: 2, Bias: -5593.116243, T: 192000, Avg. loss: 25918586191163806745247540551090176.000000
# Total training time: 0.01 seconds.
# -- Epoch 25
# Norm: 111171831271300592.00, NNZs: 2, Bias: -5638.164439, T: 200000, Avg. loss: 24028472256521886193964901424168960.000000
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 52824505613414488.00, NNZs: 2, Bias: -5680.524225, T: 208000, Avg. loss: 23090607310181640889557183348342784.000000
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 2927299157721461.00, NNZs: 2, Bias: -5721.997542, T: 216000, Avg. loss: 24480488701718482804004496101867520.000000
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 223814076351203744.00, NNZs: 2, Bias: -5762.727365, T: 224000, Avg. loss: 21374643410454877643333086761451520.000000
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 32212690435599336.00, NNZs: 2, Bias: -5800.788125, T: 232000, Avg. loss: 22080666352868765125332218115260416.000000
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 47370018879495960.00, NNZs: 2, Bias: -5837.115669, T: 240000, Avg. loss: 20022863172298342940715509025341440.000000
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 164230575684797280.00, NNZs: 2, Bias: -5872.558783, T: 248000, Avg. loss: 19244406126863554185508081792712704.000000
# Total training time: 0.02 seconds.
# -- Epoch 32
# Norm: 4153443889595510.50, NNZs: 2, Bias: -5906.541339, T: 256000, Avg. loss: 19511203523063435789474573701873664.000000
# Total training time: 0.02 seconds.
# -- Epoch 33
# Norm: 25726335641587236.00, NNZs: 2, Bias: -5940.796762, T: 264000, Avg. loss: 18124447416841946628371364983078912.000000
# Total training time: 0.02 seconds.
# -- Epoch 34
# Norm: 11003683896031718.00, NNZs: 2, Bias: -5971.852737, T: 272000, Avg. loss: 17523904413007919805534096907567104.000000
# Total training time: 0.02 seconds.
# -- Epoch 35
# Norm: 198204218319927200.00, NNZs: 2, Bias: -6004.539079, T: 280000, Avg. loss: 17177716640502162178764381016293376.000000
# Total training time: 0.02 seconds.
# -- Epoch 36
# Norm: 111576439727919904.00, NNZs: 2, Bias: -6036.087492, T: 288000, Avg. loss: 17434082360898084154486326906847232.000000
# Total training time: 0.02 seconds.
# -- Epoch 37
# Norm: 57269860883125400.00, NNZs: 2, Bias: -6065.617181, T: 296000, Avg. loss: 15954410783587895102087802728218624.000000
# Total training time: 0.02 seconds.
# -- Epoch 38
# Norm: 40033915115050160.00, NNZs: 2, Bias: -6096.220821, T: 304000, Avg. loss: 16271583650678082656776502833577984.000000
# Total training time: 0.02 seconds.
# -- Epoch 39
# Norm: 197014547023068480.00, NNZs: 2, Bias: -6124.754121, T: 312000, Avg. loss: 15276925906977856740688140888440832.000000
# Total training time: 0.02 seconds.
# -- Epoch 40
# Norm: 19949684017460516.00, NNZs: 2, Bias: -6153.257065, T: 320000, Avg. loss: 16823941357166093994519776894910464.000000
# Total training time: 0.02 seconds.
# -- Epoch 41
# Norm: 72457273133565024.00, NNZs: 2, Bias: -6179.620640, T: 328000, Avg. loss: 15514800973315953045989618614272000.000000
# Total training time: 0.02 seconds.
# -- Epoch 42
# Norm: 42898087735181336.00, NNZs: 2, Bias: -6206.412458, T: 336000, Avg. loss: 14056308620322640193951001240141824.000000
# Total training time: 0.02 seconds.
# -- Epoch 43
# Norm: 6766701443587217.00, NNZs: 2, Bias: -6232.211640, T: 344000, Avg. loss: 14605515539420831786201616627007488.000000
# Total training time: 0.02 seconds.
# -- Epoch 44
# Norm: 15552530364572162.00, NNZs: 2, Bias: -6259.084492, T: 352000, Avg. loss: 14024933663241911970487791907766272.000000
# Total training time: 0.02 seconds.
# -- Epoch 45
# Norm: 28882157872770060.00, NNZs: 2, Bias: -6284.457093, T: 360000, Avg. loss: 13816777120393435666679573365391360.000000
# Total training time: 0.02 seconds.
# -- Epoch 46
# Norm: 155219153706811008.00, NNZs: 2, Bias: -6309.140237, T: 368000, Avg. loss: 13703268598938256724706488538365952.000000
# Total training time: 0.02 seconds.
# -- Epoch 47
# Norm: 500969797568869.38, NNZs: 2, Bias: -6333.296367, T: 376000, Avg. loss: 13404838431116684300960192698253312.000000
# Total training time: 0.02 seconds.
# -- Epoch 48
# Norm: 41687735032834872.00, NNZs: 2, Bias: -6355.085341, T: 384000, Avg. loss: 13000337009616773981375003801681920.000000
# Total training time: 0.02 seconds.
# -- Epoch 49
# Norm: 20056125692827192.00, NNZs: 2, Bias: -6375.726613, T: 392000, Avg. loss: 11872582567649897698495281850482688.000000
# Total training time: 0.02 seconds.
# -- Epoch 50
# Norm: 62368683023279704.00, NNZs: 2, Bias: -6398.036060, T: 400000, Avg. loss: 12406576374104567980445002947887104.000000
# Total training time: 0.02 seconds.
# -- Epoch 51
# Norm: 25813562676563360.00, NNZs: 2, Bias: -6419.216899, T: 408000, Avg. loss: 11421210655118752229548827160346624.000000
# Total training time: 0.02 seconds.
# -- Epoch 52
# Norm: 14464384506683786.00, NNZs: 2, Bias: -6441.314641, T: 416000, Avg. loss: 12297652724558224805274739118440448.000000
# Total training time: 0.02 seconds.
# -- Epoch 53
# Norm: 14602774083254918.00, NNZs: 2, Bias: -6461.606662, T: 424000, Avg. loss: 11472584538483724636036612887674880.000000
# Total training time: 0.02 seconds.
# -- Epoch 54
# Norm: 342419382406061.44, NNZs: 2, Bias: -6481.335271, T: 432000, Avg. loss: 11674771975686125944948241545035776.000000
# Total training time: 0.02 seconds.
# -- Epoch 55
# Norm: 7857907344806078.00, NNZs: 2, Bias: -6501.356294, T: 440000, Avg. loss: 10524498967408127536583182198505472.000000
# Total training time: 0.02 seconds.
# -- Epoch 56
# Norm: 19307122145851808.00, NNZs: 2, Bias: -6521.258229, T: 448000, Avg. loss: 10370054597049961003244397357170688.000000
# Total training time: 0.03 seconds.
# -- Epoch 57
# Norm: 15125028659569586.00, NNZs: 2, Bias: -6539.737133, T: 456000, Avg. loss: 10603679763679115704574229591621632.000000
# Total training time: 0.03 seconds.
# -- Epoch 58
# Norm: 37295940044792280.00, NNZs: 2, Bias: -6558.430210, T: 464000, Avg. loss: 10769547609019228549900749372391424.000000
# Total training time: 0.03 seconds.
# -- Epoch 59
# Norm: 13999347231477256.00, NNZs: 2, Bias: -6577.685339, T: 472000, Avg. loss: 10598775772789818638418827974541312.000000
# Total training time: 0.03 seconds.
# -- Epoch 60
# Norm: 7302196420672754.00, NNZs: 2, Bias: -6595.887097, T: 480000, Avg. loss: 10367441153411387328144395888230400.000000
# Total training time: 0.03 seconds.
# -- Epoch 61
# Norm: 23274385246461688.00, NNZs: 2, Bias: -6613.784024, T: 488000, Avg. loss: 9834632643238478722465871339454464.000000
# Total training time: 0.03 seconds.
# -- Epoch 62
# Norm: 17408754094342728.00, NNZs: 2, Bias: -6631.874434, T: 496000, Avg. loss: 10129971878138763068990444892323840.000000
# Total training time: 0.03 seconds.
# -- Epoch 63
# Norm: 19549395137182224.00, NNZs: 2, Bias: -6648.736346, T: 504000, Avg. loss: 9838619830508493205430022694764544.000000
# Total training time: 0.03 seconds.
# -- Epoch 64
# Norm: 31163641105787428.00, NNZs: 2, Bias: -6665.497572, T: 512000, Avg. loss: 9649007179054247440485130122035200.000000
# Total training time: 0.03 seconds.
# -- Epoch 65
# Norm: 13175132320577586.00, NNZs: 2, Bias: -6683.092023, T: 520000, Avg. loss: 9610576121413441449633644636274688.000000
# Total training time: 0.03 seconds.
# -- Epoch 66
# Norm: 1035443588300805.38, NNZs: 2, Bias: -6699.913587, T: 528000, Avg. loss: 9633237968145547122752297447194624.000000
# Total training time: 0.03 seconds.
# -- Epoch 67
# Norm: 9599880919509740.00, NNZs: 2, Bias: -6716.519298, T: 536000, Avg. loss: 8675864880844422558028680734441472.000000
# Total training time: 0.03 seconds.
# -- Epoch 68
# Norm: 18274338023782644.00, NNZs: 2, Bias: -6733.191225, T: 544000, Avg. loss: 9344675785158531043731812204412928.000000
# Total training time: 0.03 seconds.
# -- Epoch 69
# Norm: 27002469515983900.00, NNZs: 2, Bias: -6750.002077, T: 552000, Avg. loss: 8885873666437151063846698814013440.000000
# Total training time: 0.03 seconds.
# -- Epoch 70
# Norm: 2317777556069819.00, NNZs: 2, Bias: -6765.999683, T: 560000, Avg. loss: 8457550183424364496760042734747648.000000
# Total training time: 0.03 seconds.
# -- Epoch 71
# Norm: 18194712343287224.00, NNZs: 2, Bias: -6781.751824, T: 568000, Avg. loss: 8738950154082725773789285287198720.000000
# Total training time: 0.03 seconds.
# -- Epoch 72
# Norm: 8241322909355687.00, NNZs: 2, Bias: -6796.922062, T: 576000, Avg. loss: 8422150424253557596771857450663936.000000
# Total training time: 0.03 seconds.
# -- Epoch 73
# Norm: 6665555362339177.00, NNZs: 2, Bias: -6811.571716, T: 584000, Avg. loss: 8214739971242774423941458130108416.000000
# Total training time: 0.03 seconds.
# -- Epoch 74
# Norm: 34358825994828740.00, NNZs: 2, Bias: -6827.226137, T: 592000, Avg. loss: 8947865384154596520298377883156480.000000
# Total training time: 0.03 seconds.
# -- Epoch 75
# Norm: 3192165509329816.00, NNZs: 2, Bias: -6842.166752, T: 600000, Avg. loss: 7834354180579210329919878462439424.000000
# Total training time: 0.03 seconds.
# -- Epoch 76
# Norm: 96161432414341632.00, NNZs: 2, Bias: -6856.711395, T: 608000, Avg. loss: 8081218756107333007377241751945216.000000
# Total training time: 0.03 seconds.
# -- Epoch 77
# Norm: 80316525372973776.00, NNZs: 2, Bias: -6870.965518, T: 616000, Avg. loss: 7774813505009322024985713465884672.000000
# Total training time: 0.03 seconds.
# -- Epoch 78
# Norm: 28204257261064396.00, NNZs: 2, Bias: -6884.519531, T: 624000, Avg. loss: 7800802529803370964805545898278912.000000
# Total training time: 0.03 seconds.
# -- Epoch 79
# Norm: 12547000810592460.00, NNZs: 2, Bias: -6897.875819, T: 632000, Avg. loss: 7661334282470648136136729171066880.000000
# Total training time: 0.03 seconds.
# -- Epoch 80
# Norm: 14914295788941456.00, NNZs: 2, Bias: -6911.970688, T: 640000, Avg. loss: 7725246254892460397552350191943680.000000
# Total training time: 0.03 seconds.
# -- Epoch 81
# Norm: 56483070625165280.00, NNZs: 2, Bias: -6925.878060, T: 648000, Avg. loss: 7662315232310154862842844444360704.000000
# Total training time: 0.03 seconds.
# -- Epoch 82
# Norm: 3507285882766760.00, NNZs: 2, Bias: -6940.396253, T: 656000, Avg. loss: 7700831065832148021186728885747712.000000
# Total training time: 0.03 seconds.
# -- Epoch 83
# Norm: 37579423369191408.00, NNZs: 2, Bias: -6953.905226, T: 664000, Avg. loss: 7395370481618318820381845253783552.000000
# Total training time: 0.03 seconds.
# -- Epoch 84
# Norm: 8228156161597007.00, NNZs: 2, Bias: -6966.845766, T: 672000, Avg. loss: 7434784196101141740660855461117952.000000
# Total training time: 0.03 seconds.
# -- Epoch 85
# Norm: 12537790132352102.00, NNZs: 2, Bias: -6979.388052, T: 680000, Avg. loss: 7124432595172739965011258779893760.000000
# Total training time: 0.03 seconds.
# -- Epoch 86
# Norm: 15654965164807698.00, NNZs: 2, Bias: -6992.977519, T: 688000, Avg. loss: 7461904956672076107401043902464000.000000
# Total training time: 0.03 seconds.
# -- Epoch 87
# Norm: 15078811814774230.00, NNZs: 2, Bias: -7004.953490, T: 696000, Avg. loss: 6940761816302119631610274360852480.000000
# Total training time: 0.03 seconds.
# -- Epoch 88
# Norm: 1589872270950828.75, NNZs: 2, Bias: -7016.995604, T: 704000, Avg. loss: 7159526401136277825917245951311872.000000
# Total training time: 0.03 seconds.
# -- Epoch 89
# Norm: 17692228446086220.00, NNZs: 2, Bias: -7030.157163, T: 712000, Avg. loss: 6399901877354165880910936860000256.000000
# Total training time: 0.03 seconds.
# -- Epoch 90
# Norm: 70961281215125520.00, NNZs: 2, Bias: -7041.928882, T: 720000, Avg. loss: 6682880437959749738841948576284672.000000
# Total training time: 0.04 seconds.
# -- Epoch 91
# Norm: 33884744798791624.00, NNZs: 2, Bias: -7054.248877, T: 728000, Avg. loss: 6810676123648127402368036648255488.000000
# Total training time: 0.04 seconds.
# -- Epoch 92
# Norm: 8713603328949146.00, NNZs: 2, Bias: -7066.022197, T: 736000, Avg. loss: 6513497821367778007760770313486336.000000
# Total training time: 0.04 seconds.
# -- Epoch 93
# Norm: 16509403421780372.00, NNZs: 2, Bias: -7077.895386, T: 744000, Avg. loss: 6402804059642241003519012241408000.000000
# Total training time: 0.04 seconds.
# -- Epoch 94
# Norm: 1140172332940949.00, NNZs: 2, Bias: -7089.868832, T: 752000, Avg. loss: 6863239119685813519786170004799488.000000
# Total training time: 0.04 seconds.
# Convergence after 94 epochs took 0.04 seconds
# -- Epoch 1
# Norm: 124495512836421648.00, NNZs: 2, Bias: -8876.335472, T: 8000, Avg. loss: 2863307941269117858385079889481957376.000000
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 529063404318823040.00, NNZs: 2, Bias: -11554.137524, T: 16000, Avg. loss: 864107979631530552244337512705687552.000000
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 195500102403184480.00, NNZs: 2, Bias: -13162.962760, T: 24000, Avg. loss: 495561985455414249747379723607998464.000000
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 430004039970014528.00, NNZs: 2, Bias: -14332.565839, T: 32000, Avg. loss: 353894402907844366703428410093338624.000000
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 190994175377101568.00, NNZs: 2, Bias: -15249.335144, T: 40000, Avg. loss: 275211281637310077696664199789281280.000000
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 331273366957356992.00, NNZs: 2, Bias: -16002.522373, T: 48000, Avg. loss: 241087212982284533843012556129566720.000000
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 106096268837134752.00, NNZs: 2, Bias: -16620.736188, T: 56000, Avg. loss: 186509357388681564091087637222260736.000000
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 107199615993150624.00, NNZs: 2, Bias: -17177.072955, T: 64000, Avg. loss: 174711986557503701304226370245623808.000000
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 165447558614684320.00, NNZs: 2, Bias: -17661.087709, T: 72000, Avg. loss: 145783953206530695191315601749442560.000000
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 681387553163337600.00, NNZs: 2, Bias: -18103.121475, T: 80000, Avg. loss: 136181934200856708036342953214476288.000000
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 145839775180925632.00, NNZs: 2, Bias: -18492.184403, T: 88000, Avg. loss: 117644758917007932269715862465806336.000000
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 379663840451062400.00, NNZs: 2, Bias: -18860.243563, T: 96000, Avg. loss: 112417771600459986374883938997895168.000000
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 252784798165624960.00, NNZs: 2, Bias: -19192.704226, T: 104000, Avg. loss: 101946305817591385986339456795279360.000000
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 37319153442835048.00, NNZs: 2, Bias: -19513.333841, T: 112000, Avg. loss: 97598073132012820523868245198897152.000000
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 36208794691246376.00, NNZs: 2, Bias: -19793.404719, T: 120000, Avg. loss: 82599609307488985028459092519157760.000000
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 16275954959644158.00, NNZs: 2, Bias: -20061.427079, T: 128000, Avg. loss: 84285713752852223809700411255816192.000000
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 32468821360818840.00, NNZs: 2, Bias: -20312.180508, T: 136000, Avg. loss: 74678614692129026136499243303567360.000000
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 220402486895556704.00, NNZs: 2, Bias: -20550.814426, T: 144000, Avg. loss: 73114405693103538484867084123635712.000000
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 161459392723879904.00, NNZs: 2, Bias: -20772.678377, T: 152000, Avg. loss: 69187753559143994103731298435596288.000000
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 113597900989384816.00, NNZs: 2, Bias: -20985.320069, T: 160000, Avg. loss: 66796209179388283192369096505163776.000000
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 40144393340432144.00, NNZs: 2, Bias: -21188.686413, T: 168000, Avg. loss: 60435383608420204573405575196442624.000000
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 12237203118702640.00, NNZs: 2, Bias: -21378.074090, T: 176000, Avg. loss: 57657577691534213580814468796907520.000000
# Total training time: 0.01 seconds.
# -- Epoch 23
# Norm: 53449744963902952.00, NNZs: 2, Bias: -21565.531564, T: 184000, Avg. loss: 57639003077028449666612060735143936.000000
# Total training time: 0.01 seconds.
# -- Epoch 24
# Norm: 41962994172603528.00, NNZs: 2, Bias: -21744.736429, T: 192000, Avg. loss: 52628672602348278726408381378068480.000000
# Total training time: 0.01 seconds.
# -- Epoch 25
# Norm: 47994724848446304.00, NNZs: 2, Bias: -21913.818116, T: 200000, Avg. loss: 51536545797525932738929250006990848.000000
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 44363404865836392.00, NNZs: 2, Bias: -22075.468323, T: 208000, Avg. loss: 46871951842554222027380450587049984.000000
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 37881963875114136.00, NNZs: 2, Bias: -22227.309827, T: 216000, Avg. loss: 47877857168863113155376936183136256.000000
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 9412140265790074.00, NNZs: 2, Bias: -22379.145150, T: 224000, Avg. loss: 45674113995002165644125452520914944.000000
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 33032056002163960.00, NNZs: 2, Bias: -22525.695147, T: 232000, Avg. loss: 42784777554774056281022328905662464.000000
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 39151990102480600.00, NNZs: 2, Bias: -22665.474156, T: 240000, Avg. loss: 41415111222495088182286740122238976.000000
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 35130356370985792.00, NNZs: 2, Bias: -22796.292888, T: 248000, Avg. loss: 40230672117262586800987348490256384.000000
# Total training time: 0.01 seconds.
# -- Epoch 32
# Norm: 1437209111963874.50, NNZs: 2, Bias: -22933.398454, T: 256000, Avg. loss: 42121455926340181119755533795983360.000000
# Total training time: 0.01 seconds.
# -- Epoch 33
# Norm: 2498754366579036.50, NNZs: 2, Bias: -23061.897869, T: 264000, Avg. loss: 39003472924115891693354866232524800.000000
# Total training time: 0.01 seconds.
# -- Epoch 34
# Norm: 83598243584191728.00, NNZs: 2, Bias: -23185.465705, T: 272000, Avg. loss: 38913449211655266694316813591773184.000000
# Total training time: 0.01 seconds.
# -- Epoch 35
# Norm: 11283210052271194.00, NNZs: 2, Bias: -23306.662540, T: 280000, Avg. loss: 36837614582421404503492182868492288.000000
# Total training time: 0.01 seconds.
# -- Epoch 36
# Norm: 43460856712315504.00, NNZs: 2, Bias: -23425.596413, T: 288000, Avg. loss: 35909108929246129930824735705268224.000000
# Total training time: 0.01 seconds.
# -- Epoch 37
# Norm: 15030863903475108.00, NNZs: 2, Bias: -23538.986036, T: 296000, Avg. loss: 35207026648385502822982989264191488.000000
# Total training time: 0.01 seconds.
# -- Epoch 38
# Norm: 124929875920823424.00, NNZs: 2, Bias: -23649.356281, T: 304000, Avg. loss: 33723811229988935233575644712402944.000000
# Total training time: 0.01 seconds.
# -- Epoch 39
# Norm: 27235497452745912.00, NNZs: 2, Bias: -23758.199573, T: 312000, Avg. loss: 33073334545452966894416737119240192.000000
# Total training time: 0.01 seconds.
# -- Epoch 40
# Norm: 84206586690176704.00, NNZs: 2, Bias: -23865.255833, T: 320000, Avg. loss: 32091107157188216906631337285255168.000000
# Total training time: 0.01 seconds.
# -- Epoch 41
# Norm: 26490099478861256.00, NNZs: 2, Bias: -23968.467341, T: 328000, Avg. loss: 30851805585006733957496014295269376.000000
# Total training time: 0.01 seconds.
# -- Epoch 42
# Norm: 56876614647801616.00, NNZs: 2, Bias: -24068.978218, T: 336000, Avg. loss: 30799785424912137705740584345403392.000000
# Total training time: 0.01 seconds.
# -- Epoch 43
# Norm: 67733062384782392.00, NNZs: 2, Bias: -24168.216603, T: 344000, Avg. loss: 29969932025522897693205019760787456.000000
# Total training time: 0.01 seconds.
# -- Epoch 44
# Norm: 34514278104350564.00, NNZs: 2, Bias: -24263.155858, T: 352000, Avg. loss: 28790156212263095801268192361316352.000000
# Total training time: 0.01 seconds.
# -- Epoch 45
# Norm: 40715266568385400.00, NNZs: 2, Bias: -24357.218014, T: 360000, Avg. loss: 28517424426240025088778393616384000.000000
# Total training time: 0.01 seconds.
# -- Epoch 46
# Norm: 57615594506125624.00, NNZs: 2, Bias: -24449.358256, T: 368000, Avg. loss: 27980081935858823529684561081401344.000000
# Total training time: 0.01 seconds.
# -- Epoch 47
# Norm: 16871363459382762.00, NNZs: 2, Bias: -24539.231318, T: 376000, Avg. loss: 27506786370405171307729607049871360.000000
# Total training time: 0.01 seconds.
# -- Epoch 48
# Norm: 17971994635917196.00, NNZs: 2, Bias: -24629.306194, T: 384000, Avg. loss: 27855662265562014994612603961999360.000000
# Total training time: 0.02 seconds.
# -- Epoch 49
# Norm: 130607041120707632.00, NNZs: 2, Bias: -24716.270267, T: 392000, Avg. loss: 26413535613532100857861406139088896.000000
# Total training time: 0.02 seconds.
# -- Epoch 50
# Norm: 103982410126682208.00, NNZs: 2, Bias: -24800.402232, T: 400000, Avg. loss: 25174972040029679490950089207185408.000000
# Total training time: 0.02 seconds.
# -- Epoch 51
# Norm: 19014424904719380.00, NNZs: 2, Bias: -24884.356883, T: 408000, Avg. loss: 25702224781145578543350850670034944.000000
# Total training time: 0.02 seconds.
# -- Epoch 52
# Norm: 113356687921604496.00, NNZs: 2, Bias: -24964.075204, T: 416000, Avg. loss: 24931854240787712808667984879943680.000000
# Total training time: 0.02 seconds.
# -- Epoch 53
# Norm: 42858124903509368.00, NNZs: 2, Bias: -25043.091578, T: 424000, Avg. loss: 23737799941891504414575014486999040.000000
# Total training time: 0.02 seconds.
# -- Epoch 54
# Norm: 128043127405286960.00, NNZs: 2, Bias: -25120.896955, T: 432000, Avg. loss: 24077756756804557788340679321059328.000000
# Total training time: 0.02 seconds.
# -- Epoch 55
# Norm: 21087057549106376.00, NNZs: 2, Bias: -25196.070502, T: 440000, Avg. loss: 22744665935921270076640237570752512.000000
# Total training time: 0.02 seconds.
# -- Epoch 56
# Norm: 26291521647806532.00, NNZs: 2, Bias: -25270.660141, T: 448000, Avg. loss: 22241052940925315892270930566578176.000000
# Total training time: 0.02 seconds.
# -- Epoch 57
# Norm: 29202598026260520.00, NNZs: 2, Bias: -25342.878958, T: 456000, Avg. loss: 23143581030802803806534399445434368.000000
# Total training time: 0.02 seconds.
# -- Epoch 58
# Norm: 17647644945634586.00, NNZs: 2, Bias: -25414.417901, T: 464000, Avg. loss: 22335251494507531169883144994160640.000000
# Total training time: 0.02 seconds.
# -- Epoch 59
# Norm: 47875732310373104.00, NNZs: 2, Bias: -25486.148160, T: 472000, Avg. loss: 21504342103658976582699939163799552.000000
# Total training time: 0.02 seconds.
# -- Epoch 60
# Norm: 1261625968171307.75, NNZs: 2, Bias: -25555.773080, T: 480000, Avg. loss: 21520271347408426737397891980066816.000000
# Total training time: 0.02 seconds.
# -- Epoch 61
# Norm: 14039610724256602.00, NNZs: 2, Bias: -25625.399699, T: 488000, Avg. loss: 20626324516893075353267028986167296.000000
# Total training time: 0.02 seconds.
# -- Epoch 62
# Norm: 18986741785793108.00, NNZs: 2, Bias: -25693.379628, T: 496000, Avg. loss: 20253594069616384032307763048611840.000000
# Total training time: 0.02 seconds.
# -- Epoch 63
# Norm: 6875187053191113.00, NNZs: 2, Bias: -25759.764787, T: 504000, Avg. loss: 20326807773787746753018761085714432.000000
# Total training time: 0.02 seconds.
# -- Epoch 64
# Norm: 15899439315080014.00, NNZs: 2, Bias: -25825.661470, T: 512000, Avg. loss: 19159452864115333723307846687260672.000000
# Total training time: 0.02 seconds.
# -- Epoch 65
# Norm: 15833102609993448.00, NNZs: 2, Bias: -25890.145335, T: 520000, Avg. loss: 20100121315876566955497862574637056.000000
# Total training time: 0.02 seconds.
# -- Epoch 66
# Norm: 8578552131858434.00, NNZs: 2, Bias: -25952.659621, T: 528000, Avg. loss: 19238059613945872777433961000337408.000000
# Total training time: 0.02 seconds.
# -- Epoch 67
# Norm: 37752975868236520.00, NNZs: 2, Bias: -26015.141042, T: 536000, Avg. loss: 18992311361015716653790976639238144.000000
# Total training time: 0.02 seconds.
# -- Epoch 68
# Norm: 14046900417712670.00, NNZs: 2, Bias: -26077.502329, T: 544000, Avg. loss: 18544403913256933757635563498766336.000000
# Total training time: 0.02 seconds.
# -- Epoch 69
# Norm: 10239145686478380.00, NNZs: 2, Bias: -26138.427447, T: 552000, Avg. loss: 18762599333598660075394657519927296.000000
# Total training time: 0.02 seconds.
# -- Epoch 70
# Norm: 1396205595517848.75, NNZs: 2, Bias: -26200.298837, T: 560000, Avg. loss: 19504835591932390387731527421132800.000000
# Total training time: 0.02 seconds.
# -- Epoch 71
# Norm: 16524749427472450.00, NNZs: 2, Bias: -26259.308759, T: 568000, Avg. loss: 17551441277446186426361858364538880.000000
# Total training time: 0.02 seconds.
# -- Epoch 72
# Norm: 19983897648445088.00, NNZs: 2, Bias: -26316.606219, T: 576000, Avg. loss: 17994072816154022482353271854858240.000000
# Total training time: 0.02 seconds.
# -- Epoch 73
# Norm: 15431270699981386.00, NNZs: 2, Bias: -26375.302292, T: 584000, Avg. loss: 17376262806672859036553876525285376.000000
# Total training time: 0.02 seconds.
# -- Epoch 74
# Norm: 17511811133779238.00, NNZs: 2, Bias: -26431.581130, T: 592000, Avg. loss: 16970928484849204370882157304872960.000000
# Total training time: 0.02 seconds.
# -- Epoch 75
# Norm: 6196064225048504.00, NNZs: 2, Bias: -26486.274430, T: 600000, Avg. loss: 16341810054478323124815876415553536.000000
# Total training time: 0.02 seconds.
# -- Epoch 76
# Norm: 57491136353597416.00, NNZs: 2, Bias: -26541.745249, T: 608000, Avg. loss: 16895509516259251890745169292558336.000000
# Total training time: 0.02 seconds.
# -- Epoch 77
# Norm: 57440513964686960.00, NNZs: 2, Bias: -26595.285705, T: 616000, Avg. loss: 16076217094406090913641365975859200.000000
# Total training time: 0.02 seconds.
# -- Epoch 78
# Norm: 9292918707753258.00, NNZs: 2, Bias: -26648.254585, T: 624000, Avg. loss: 16080814021645901102328446481072128.000000
# Total training time: 0.02 seconds.
# -- Epoch 79
# Norm: 87153265948184112.00, NNZs: 2, Bias: -26700.618135, T: 632000, Avg. loss: 15565835300797786026232884244774912.000000
# Total training time: 0.02 seconds.
# -- Epoch 80
# Norm: 33530375580810728.00, NNZs: 2, Bias: -26754.310746, T: 640000, Avg. loss: 16149463587116184841597225881567232.000000
# Total training time: 0.02 seconds.
# -- Epoch 81
# Norm: 18722066993806224.00, NNZs: 2, Bias: -26805.655164, T: 648000, Avg. loss: 15680816045139671405518526653399040.000000
# Total training time: 0.02 seconds.
# -- Epoch 82
# Norm: 7804564728124707.00, NNZs: 2, Bias: -26856.908209, T: 656000, Avg. loss: 16232888432742881637720090914848768.000000
# Total training time: 0.02 seconds.
# -- Epoch 83
# Norm: 5331564751319634.00, NNZs: 2, Bias: -26907.516860, T: 664000, Avg. loss: 15213739354129215012987988122533888.000000
# Total training time: 0.02 seconds.
# -- Epoch 84
# Norm: 859245062719785.62, NNZs: 2, Bias: -26957.850723, T: 672000, Avg. loss: 14712305767550770794232166114918400.000000
# Total training time: 0.02 seconds.
# -- Epoch 85
# Norm: 60445704229160312.00, NNZs: 2, Bias: -27005.975723, T: 680000, Avg. loss: 14036913023437573400603829332869120.000000
# Total training time: 0.03 seconds.
# -- Epoch 86
# Norm: 6592073184231515.00, NNZs: 2, Bias: -27054.780283, T: 688000, Avg. loss: 14929530039256716198769433388253184.000000
# Total training time: 0.03 seconds.
# -- Epoch 87
# Norm: 3348617152710606.00, NNZs: 2, Bias: -27102.389182, T: 696000, Avg. loss: 14779204744027839916253647046967296.000000
# Total training time: 0.03 seconds.
# -- Epoch 88
# Norm: 13084140742563896.00, NNZs: 2, Bias: -27150.803657, T: 704000, Avg. loss: 14519017731076725341709998810464256.000000
# Total training time: 0.03 seconds.
# -- Epoch 89
# Norm: 22516680537922468.00, NNZs: 2, Bias: -27198.857244, T: 712000, Avg. loss: 14751201011347451904989902585987072.000000
# Total training time: 0.03 seconds.
# -- Epoch 90
# Norm: 3972338943059884.00, NNZs: 2, Bias: -27246.418042, T: 720000, Avg. loss: 14538030702870683450373864043839488.000000
# Total training time: 0.03 seconds.
# Convergence after 90 epochs took 0.03 seconds
# -- Epoch 1
# Norm: 1189668174797128704.00, NNZs: 2, Bias: 967.303890, T: 8000, Avg. loss: 1583903489185768420468017532124528640.000000
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 181604042737739072.00, NNZs: 2, Bias: 1147.543262, T: 16000, Avg. loss: 459480377084859925539684397650804736.000000
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 111016076792913088.00, NNZs: 2, Bias: 1283.645097, T: 24000, Avg. loss: 263585151244174338669770064122609664.000000
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 718454006598606336.00, NNZs: 2, Bias: 1356.369184, T: 32000, Avg. loss: 186963506346284342871892356187029504.000000
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 228542989737571296.00, NNZs: 2, Bias: 1399.347721, T: 40000, Avg. loss: 144201964683417648377128151437803520.000000
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 227333593644671360.00, NNZs: 2, Bias: 1444.896688, T: 48000, Avg. loss: 124528130327271600934822406227230720.000000
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 452237967157243072.00, NNZs: 2, Bias: 1488.089151, T: 56000, Avg. loss: 104551881723456608090468804752048128.000000
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 127433271761769056.00, NNZs: 2, Bias: 1527.881278, T: 64000, Avg. loss: 89926303263895528362287625112911872.000000
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 149482442499127616.00, NNZs: 2, Bias: 1565.714971, T: 72000, Avg. loss: 79029446903493487108783758448263168.000000
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 154587246694334048.00, NNZs: 2, Bias: 1599.585611, T: 80000, Avg. loss: 73864430984077987294230080984711168.000000
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 93552348312840000.00, NNZs: 2, Bias: 1625.690679, T: 88000, Avg. loss: 60533064205006848966551737320079360.000000
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 30563089078181960.00, NNZs: 2, Bias: 1654.009899, T: 96000, Avg. loss: 58040013264755714038644929265139712.000000
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 413314765462117952.00, NNZs: 2, Bias: 1681.753140, T: 104000, Avg. loss: 57151068292132616144497884306341888.000000
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 104793100901276224.00, NNZs: 2, Bias: 1699.521894, T: 112000, Avg. loss: 50708604773990332441333833255616512.000000
# Total training time: 0.01 seconds.
# -- Epoch 15
# Norm: 40199004867758216.00, NNZs: 2, Bias: 1723.168921, T: 120000, Avg. loss: 46876312173970236788660400170205184.000000
# Total training time: 0.01 seconds.
# -- Epoch 16
# Norm: 69674859814873776.00, NNZs: 2, Bias: 1742.807731, T: 128000, Avg. loss: 42390506873135955083909470636474368.000000
# Total training time: 0.01 seconds.
# -- Epoch 17
# Norm: 374377940422984896.00, NNZs: 2, Bias: 1763.444211, T: 136000, Avg. loss: 40970721551529863585485922745974784.000000
# Total training time: 0.01 seconds.
# -- Epoch 18
# Norm: 47294320891820424.00, NNZs: 2, Bias: 1777.296856, T: 144000, Avg. loss: 39973099420764352601018552094294016.000000
# Total training time: 0.01 seconds.
# -- Epoch 19
# Norm: 47150979148509912.00, NNZs: 2, Bias: 1794.025883, T: 152000, Avg. loss: 37273630939868285845065219899916288.000000
# Total training time: 0.01 seconds.
# -- Epoch 20
# Norm: 25836096481931592.00, NNZs: 2, Bias: 1808.071524, T: 160000, Avg. loss: 37401317100644297279565332622606336.000000
# Total training time: 0.01 seconds.
# -- Epoch 21
# Norm: 4930141502427186.00, NNZs: 2, Bias: 1822.615839, T: 168000, Avg. loss: 34886302803585985901098501098438656.000000
# Total training time: 0.01 seconds.
# -- Epoch 22
# Norm: 260276059504516512.00, NNZs: 2, Bias: 1836.346061, T: 176000, Avg. loss: 33279309054044200802022716124168192.000000
# Total training time: 0.01 seconds.
# -- Epoch 23
# Norm: 57521094154632872.00, NNZs: 2, Bias: 1847.756899, T: 184000, Avg. loss: 31419741760821016930920023761879040.000000
# Total training time: 0.01 seconds.
# -- Epoch 24
# Norm: 58137439151189816.00, NNZs: 2, Bias: 1857.405413, T: 192000, Avg. loss: 29279156409722051118600979663028224.000000
# Total training time: 0.01 seconds.
# -- Epoch 25
# Norm: 23627934230972880.00, NNZs: 2, Bias: 1870.451231, T: 200000, Avg. loss: 28089267167889178737016805743656960.000000
# Total training time: 0.01 seconds.
# -- Epoch 26
# Norm: 21859460422130080.00, NNZs: 2, Bias: 1882.803768, T: 208000, Avg. loss: 28446339912976766145942198859857920.000000
# Total training time: 0.01 seconds.
# -- Epoch 27
# Norm: 45899992730442880.00, NNZs: 2, Bias: 1892.552784, T: 216000, Avg. loss: 27181975882085140467846269250830336.000000
# Total training time: 0.01 seconds.
# -- Epoch 28
# Norm: 1734810065900610.00, NNZs: 2, Bias: 1902.618288, T: 224000, Avg. loss: 26452247874445169777332498691260416.000000
# Total training time: 0.01 seconds.
# -- Epoch 29
# Norm: 10109973165096796.00, NNZs: 2, Bias: 1912.482813, T: 232000, Avg. loss: 24213922212458479008783849641476096.000000
# Total training time: 0.01 seconds.
# -- Epoch 30
# Norm: 118310351899742992.00, NNZs: 2, Bias: 1921.248654, T: 240000, Avg. loss: 22931405888219167636241354575577088.000000
# Total training time: 0.01 seconds.
# -- Epoch 31
# Norm: 5891948019853819.00, NNZs: 2, Bias: 1929.126593, T: 248000, Avg. loss: 22459962180649135218348507631976448.000000
# Total training time: 0.01 seconds.
# -- Epoch 32
# Norm: 26537932472447192.00, NNZs: 2, Bias: 1937.571925, T: 256000, Avg. loss: 21206802891735461460540554448207872.000000
# Total training time: 0.01 seconds.
# -- Epoch 33
# Norm: 181381683661952800.00, NNZs: 2, Bias: 1945.035578, T: 264000, Avg. loss: 20610847807727977878184216301142016.000000
# Total training time: 0.01 seconds.
# -- Epoch 34
# Norm: 51566340064369920.00, NNZs: 2, Bias: 1957.159605, T: 272000, Avg. loss: 20894945776407161797503781875744768.000000
# Total training time: 0.01 seconds.
# -- Epoch 35
# Norm: 149988443126070432.00, NNZs: 2, Bias: 1965.702921, T: 280000, Avg. loss: 20220582843315711298312354723266560.000000
# Total training time: 0.01 seconds.
# -- Epoch 36
# Norm: 38709629246181016.00, NNZs: 2, Bias: 1974.197832, T: 288000, Avg. loss: 19372506651045280900874865572052992.000000
# Total training time: 0.01 seconds.
# -- Epoch 37
# Norm: 53320478566363040.00, NNZs: 2, Bias: 1981.542949, T: 296000, Avg. loss: 18554383442633455237467455212224512.000000
# Total training time: 0.01 seconds.
# -- Epoch 38
# Norm: 138665771604926800.00, NNZs: 2, Bias: 1988.459869, T: 304000, Avg. loss: 18166593715365699064821673468362752.000000
# Total training time: 0.01 seconds.
# -- Epoch 39
# Norm: 47550807087304608.00, NNZs: 2, Bias: 1996.117640, T: 312000, Avg. loss: 18153239127407408396195428229447680.000000
# Total training time: 0.01 seconds.
# -- Epoch 40
# Norm: 23859413973970068.00, NNZs: 2, Bias: 2003.210454, T: 320000, Avg. loss: 17301264211598659766690075933409280.000000
# Total training time: 0.01 seconds.
# -- Epoch 41
# Norm: 29681221375233452.00, NNZs: 2, Bias: 2012.437529, T: 328000, Avg. loss: 16575510466683815287992306680987648.000000
# Total training time: 0.01 seconds.
# -- Epoch 42
# Norm: 6207928139210973.00, NNZs: 2, Bias: 2019.911622, T: 336000, Avg. loss: 16918564645714740227862007849680896.000000
# Total training time: 0.01 seconds.
# -- Epoch 43
# Norm: 16902337021209274.00, NNZs: 2, Bias: 2027.999403, T: 344000, Avg. loss: 16752378182081841109270121118957568.000000
# Total training time: 0.01 seconds.
# -- Epoch 44
# Norm: 6263227140809542.00, NNZs: 2, Bias: 2035.381344, T: 352000, Avg. loss: 15617137126855318344085858420785152.000000
# Total training time: 0.01 seconds.
# -- Epoch 45
# Norm: 9248850221826204.00, NNZs: 2, Bias: 2041.007981, T: 360000, Avg. loss: 15439288106726355244993756906127360.000000
# Total training time: 0.01 seconds.
# -- Epoch 46
# Norm: 49032442218739344.00, NNZs: 2, Bias: 2045.341130, T: 368000, Avg. loss: 15402131361335547048605568305463296.000000
# Total training time: 0.01 seconds.
# -- Epoch 47
# Norm: 3877889579886060.50, NNZs: 2, Bias: 2050.488505, T: 376000, Avg. loss: 15601436717476637555360304862330880.000000
# Total training time: 0.01 seconds.
# -- Epoch 48
# Norm: 4044227614821815.50, NNZs: 2, Bias: 2056.375966, T: 384000, Avg. loss: 14349897974682078856541235597803520.000000
# Total training time: 0.02 seconds.
# -- Epoch 49
# Norm: 28252295893308804.00, NNZs: 2, Bias: 2060.819064, T: 392000, Avg. loss: 14397975664690324909311696872407040.000000
# Total training time: 0.02 seconds.
# -- Epoch 50
# Norm: 17486399336350338.00, NNZs: 2, Bias: 2065.739043, T: 400000, Avg. loss: 13931152969455687423667300198252544.000000
# Total training time: 0.02 seconds.
# -- Epoch 51
# Norm: 11894433879980192.00, NNZs: 2, Bias: 2070.970203, T: 408000, Avg. loss: 13446061353030595195272672703414272.000000
# Total training time: 0.02 seconds.
# -- Epoch 52
# Norm: 13625656473343834.00, NNZs: 2, Bias: 2077.233508, T: 416000, Avg. loss: 12893766520495809505943729037377536.000000
# Total training time: 0.02 seconds.
# -- Epoch 53
# Norm: 12515626354361090.00, NNZs: 2, Bias: 2083.391379, T: 424000, Avg. loss: 13101053446912913914873763174809600.000000
# Total training time: 0.02 seconds.
# -- Epoch 54
# Norm: 16482145282038992.00, NNZs: 2, Bias: 2089.722603, T: 432000, Avg. loss: 12622456442543103878857922243985408.000000
# Total training time: 0.02 seconds.
# -- Epoch 55
# Norm: 10504366075733220.00, NNZs: 2, Bias: 2094.122199, T: 440000, Avg. loss: 12421123752510006355900476025733120.000000
# Total training time: 0.02 seconds.
# -- Epoch 56
# Norm: 18055225420830852.00, NNZs: 2, Bias: 2099.173063, T: 448000, Avg. loss: 11998555865334906768378778917797888.000000
# Total training time: 0.02 seconds.
# -- Epoch 57
# Norm: 19057308128634344.00, NNZs: 2, Bias: 2103.352452, T: 456000, Avg. loss: 11973713017153346690251137428226048.000000
# Total training time: 0.02 seconds.
# -- Epoch 58
# Norm: 17913013423098012.00, NNZs: 2, Bias: 2107.403802, T: 464000, Avg. loss: 12578386577314288523722017501872128.000000
# Total training time: 0.02 seconds.
# -- Epoch 59
# Norm: 25867672257301772.00, NNZs: 2, Bias: 2112.928633, T: 472000, Avg. loss: 11635749509942152209526323559792640.000000
# Total training time: 0.02 seconds.
# -- Epoch 60
# Norm: 3329277561000178.00, NNZs: 2, Bias: 2118.918539, T: 480000, Avg. loss: 11659339824244452645986437668274176.000000
# Total training time: 0.02 seconds.
# -- Epoch 61
# Norm: 37905918263700472.00, NNZs: 2, Bias: 2123.503523, T: 488000, Avg. loss: 12002444399152704819782858854891520.000000
# Total training time: 0.02 seconds.
# -- Epoch 62
# Norm: 26757149247229048.00, NNZs: 2, Bias: 2127.251612, T: 496000, Avg. loss: 10868029193129368346084859231338496.000000
# Total training time: 0.02 seconds.
# -- Epoch 63
# Norm: 4084305350077192.00, NNZs: 2, Bias: 2132.615801, T: 504000, Avg. loss: 10751554953282850366496391867400192.000000
# Total training time: 0.02 seconds.
# -- Epoch 64
# Norm: 31869658946649648.00, NNZs: 2, Bias: 2136.969700, T: 512000, Avg. loss: 11209641936553500684342279209484288.000000
# Total training time: 0.02 seconds.
# -- Epoch 65
# Norm: 24480807676640628.00, NNZs: 2, Bias: 2141.402202, T: 520000, Avg. loss: 10619755061737244268731715144384512.000000
# Total training time: 0.02 seconds.
# -- Epoch 66
# Norm: 3892426089146527.50, NNZs: 2, Bias: 2145.822749, T: 528000, Avg. loss: 10687819772768953750489393323311104.000000
# Total training time: 0.02 seconds.
# -- Epoch 67
# Norm: 13159564570831072.00, NNZs: 2, Bias: 2150.604569, T: 536000, Avg. loss: 10587251829193473791503392367968256.000000
# Total training time: 0.02 seconds.
# -- Epoch 68
# Norm: 23203889580476108.00, NNZs: 2, Bias: 2155.453665, T: 544000, Avg. loss: 9903246725905533929794667194351616.000000
# Total training time: 0.02 seconds.
# -- Epoch 69
# Norm: 10136890337908792.00, NNZs: 2, Bias: 2160.226430, T: 552000, Avg. loss: 10286783080026129990979645176020992.000000
# Total training time: 0.02 seconds.
# -- Epoch 70
# Norm: 7911036909108594.00, NNZs: 2, Bias: 2164.900496, T: 560000, Avg. loss: 9863996173442730726019064632705024.000000
# Total training time: 0.02 seconds.
# -- Epoch 71
# Norm: 4570389932541257.00, NNZs: 2, Bias: 2169.409695, T: 568000, Avg. loss: 9632452873826848798629074879643648.000000
# Total training time: 0.02 seconds.
# -- Epoch 72
# Norm: 13487406312609956.00, NNZs: 2, Bias: 2172.774156, T: 576000, Avg. loss: 9776028837797999866268802745368576.000000
# Total training time: 0.02 seconds.
# -- Epoch 73
# Norm: 17475419816903748.00, NNZs: 2, Bias: 2176.734862, T: 584000, Avg. loss: 9643990029921245010150715820081152.000000
# Total training time: 0.02 seconds.
# -- Epoch 74
# Norm: 18003473985688792.00, NNZs: 2, Bias: 2182.679148, T: 592000, Avg. loss: 9729071672925062461522697993060352.000000
# Total training time: 0.02 seconds.
# -- Epoch 75
# Norm: 10894695509011356.00, NNZs: 2, Bias: 2186.548092, T: 600000, Avg. loss: 9465407350571217091798021110235136.000000
# Total training time: 0.02 seconds.
# -- Epoch 76
# Norm: 21834692723286712.00, NNZs: 2, Bias: 2189.982651, T: 608000, Avg. loss: 9060594539962206353248877107216384.000000
# Total training time: 0.02 seconds.
# -- Epoch 77
# Norm: 22893104632324456.00, NNZs: 2, Bias: 2193.980651, T: 616000, Avg. loss: 9638431454144773002848966547603456.000000
# Total training time: 0.02 seconds.
# -- Epoch 78
# Norm: 1778259245217341.50, NNZs: 2, Bias: 2197.393362, T: 624000, Avg. loss: 9096305119078209641884796256780288.000000
# Total training time: 0.02 seconds.
# -- Epoch 79
# Norm: 675819458355853.12, NNZs: 2, Bias: 2200.619134, T: 632000, Avg. loss: 9146615295009000376834463992119296.000000
# Total training time: 0.02 seconds.
# -- Epoch 80
# Norm: 13191776648587364.00, NNZs: 2, Bias: 2203.586052, T: 640000, Avg. loss: 8285097935652056336274276327882752.000000
# Total training time: 0.02 seconds.
# -- Epoch 81
# Norm: 11227580283205544.00, NNZs: 2, Bias: 2206.666572, T: 648000, Avg. loss: 8411701504702543034492051146145792.000000
# Total training time: 0.02 seconds.
# -- Epoch 82
# Norm: 10990943247323218.00, NNZs: 2, Bias: 2209.895438, T: 656000, Avg. loss: 8856853686633541685788248551456768.000000
# Total training time: 0.03 seconds.
# -- Epoch 83
# Norm: 19516126704649568.00, NNZs: 2, Bias: 2213.709322, T: 664000, Avg. loss: 8273949532541806063820596890828800.000000
# Total training time: 0.03 seconds.
# -- Epoch 84
# Norm: 16866663932585598.00, NNZs: 2, Bias: 2217.208349, T: 672000, Avg. loss: 8348637602413806939050060208406528.000000
# Total training time: 0.03 seconds.
# -- Epoch 85
# Norm: 9975875085675274.00, NNZs: 2, Bias: 2220.426272, T: 680000, Avg. loss: 8079166964496685785693414060195840.000000
# Total training time: 0.03 seconds.
# -- Epoch 86
# Norm: 18454024514135200.00, NNZs: 2, Bias: 2224.123142, T: 688000, Avg. loss: 8289189466813469461979815187841024.000000
# Total training time: 0.03 seconds.
# -- Epoch 87
# Norm: 15343504800531634.00, NNZs: 2, Bias: 2227.343466, T: 696000, Avg. loss: 7743412297673555108070426371162112.000000
# Total training time: 0.03 seconds.
# -- Epoch 88
# Norm: 10111860233090564.00, NNZs: 2, Bias: 2231.338558, T: 704000, Avg. loss: 7494933359078846801624787260014592.000000
# Total training time: 0.03 seconds.
# -- Epoch 89
# Norm: 27539301831014232.00, NNZs: 2, Bias: 2234.733367, T: 712000, Avg. loss: 8158591823230514377317293093814272.000000
# Total training time: 0.03 seconds.
# -- Epoch 90
# Norm: 43733221082773968.00, NNZs: 2, Bias: 2238.793504, T: 720000, Avg. loss: 8139146737997895442017917337600000.000000
# Total training time: 0.03 seconds.
# -- Epoch 91
# Norm: 3148741032325644.00, NNZs: 2, Bias: 2241.069019, T: 728000, Avg. loss: 7777731974175888885800965322571776.000000
# Total training time: 0.03 seconds.
# -- Epoch 92
# Norm: 12288488525716782.00, NNZs: 2, Bias: 2243.864049, T: 736000, Avg. loss: 7730173251277997449777037183025152.000000
# Total training time: 0.03 seconds.
# -- Epoch 93
# Norm: 59401337303751408.00, NNZs: 2, Bias: 2246.939323, T: 744000, Avg. loss: 7936223351158301888865020927803392.000000
# Total training time: 0.03 seconds.
# Convergence after 93 epochs took 0.03 seconds

# %%
# Scatter plot of PCA projection
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_test_pca[:, 0], y=X_test_pca[:, 1], hue=le.inverse_transform(y_test), alpha=0.6)
plt.title("PCA Projection of Data with SVM Predictions")
plt.show()
